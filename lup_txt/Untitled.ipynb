# %%
import pandas as pd

# %%
df = pd.read_json('country.json')

# %%
df
# Out:
#                        name                            enName alpha2 alpha3  \
# 0                      กรีซ                            Greece     GR    GRC
# 1                 กรีนแลนด์                         Greenland     GL    GRL
# 2                       กวม                              Guam     GU    GUM
# 3                   กัมพูชา                          Cambodia     KH    KHM
# 4                 กัวเดอลุป                        Guadeloupe     GP    GLP
# ..                      ...                               ...    ...    ...
# 244                 ฮังการี                           Hungary     HU    HUN
# 245                    เฮติ                             Haiti     HT    HTI
# 246           ซินต์มาร์เติน                      Sint Maarten     SX    SXM
# 247  เนเธอร์แลนด์แคริบเบียน  Bonaire, Sint Eustatius and Saba     BQ    BES
# 248     สฟาลบาร์และยานไมเอน            Svalbard and Jan Mayen     SJ    SJM
#
#      numeric      iso3166_2
# ...

# %%
th = df['name']

# %%
th
# Out:
# 0                        กรีซ
# 1                   กรีนแลนด์
# 2                         กวม
# 3                     กัมพูชา
# 4                   กัวเดอลุป
#                 ...
# 244                   ฮังการี
# 245                      เฮติ
# 246             ซินต์มาร์เติน
# 247    เนเธอร์แลนด์แคริบเบียน
# 248       สฟาลบาร์และยานไมเอน
# Name: name, Length: 249, dtype: object

# %%
en = df['enName']

# %%
f = open('country_th.txt', 'w+', encoding="utf-8")
for i in th:
    with open('country_th.txt', encoding="utf-8") as write_file:
        f.writelines(i)
    write_file.close()

# %%
for i in th:
    print('-',i)
# Out:
# - กรีซ
# - กรีนแลนด์
# - กวม
# - กัมพูชา
# - กัวเดอลุป
# - กัวเตมาลา
# - กาตาร์
# - กานา
# - กาบอง
# - กาบูเวร์ดี
# - กายอานา
# - กินี
# - กินี-บิสเซา
# - กือราเซา
# - เกรเนดา
# - เกาหลีใต้
# - เกาหลีเหนือ
# - เกาะคริสต์มาส
# - เกาะเซาท์จอร์เจียและหมู่เกาะเซาท์แซนด์วิช
# - เกาะเซาท์จอร์เจียและหมู่เกาะเซาท์แซนด์วิช
# - เกาะนอร์ฟอล์ก
# - เกาะบูเวต์
# - เกาะเล็กรอบนอกของสหรัฐอเมริกา
# - เกาะเฮิร์ดและหมู่เกาะแมกดอนัลด์
# - เกิร์นซีย์
# - แกมเบีย
# - โกตดิวัวร์
# - คอโมโรส
# - คอสตาริกา
# - คาซัคสถาน
# - คิริบาส
# - คิวบา
# - คีร์กีซสถาน
# - คูเวต
# - เคนยา
# - แคนาดา
# - แคเมอรูน
# - โครเอเชีย
# - โคลอมเบีย
# - จอร์เจีย
# - จอร์แดน
# - จาเมกา
# - จิบูตี
# - จีน
# - เจอร์ซีย์
# - ชาด
# - ชิลี
# - เช็กเกีย
# - ซานมารีโน
# - ซามัว
# - ซาอุดีอาระเบีย
# - ซาฮาราตะวันตก
# - ซิมบับเว
# - ซีเรีย
# - ซูดาน
# - ซูรินาม
# - เซเชลส์
# - เซนต์คิตส์และเนวิส
# - เซนต์ลูเชีย
# - เซนต์วินเซนต์และเกรนาดีนส์
# - เซนต์เฮเลนา
# - เซเนกัล
# - เซอร์เบีย
# - เซาตูเมและปรินซีปี
# - เซียร์ราลีโอน
# ...

# %%
for i in en:
    print('-', i)
# Out:
# - Greece
# - Greenland
# - Guam
# - Cambodia
# - Guadeloupe
# - Guatemala
# - Qatar
# - Ghana
# - Gabon
# - Cabo Verde
# - Guyana
# - Guinea
# - Guinea-Bissau
# - Curaçao
# - Grenada
# - South Korea
# - North Korea
# - Christmas Island
# - South Georgia and the South Sandwich Islands
# - South Sudan
# - Norfolk Island
# - Bouvet Island
